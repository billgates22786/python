# %%
no=int(input("Enter your no: "))
if no==10:
    print("Excellent")
else:
    print("Work Hard")
# Out:
# Enter your no:  2
# Work Hard

# %%
no=int(input("Enter a number: "))
if no%50==0:
    print(f"{no} is divisible by 50")
else:
    print(f"{no} is not divisible by 50")
# Out:
# Enter a number:  52
# 52 is not divisible by 50

# %%
character=input("Enter any character: ")
if character==('a' or 'e' or 'i' or 'o' or 'u' or 'A' or 'E' or 'I' or 'O' or 'U'):
    print("Character is vowels")
else:
    print("Character is consonants")
# Out:
# Enter any character:  h
# Character is consonants

# %%
character=input("Enter any character: ")
if character in "aeiouAEIOU":
    print("Character is vowels")
else:
    print("Character is consonants")

# %%
num=input("Enter any number: ")
if num in "123456789":
    print("Wow")
else:
    print("Hoo")
# Out:
# Enter any number:  231
# Hoo

# %%
no=int(input("Enter your number: "))
if no==10:
    print("Excellent")
elif no==9:
    print("Very Good")
elif no==8:
    print("Good")
else:
    print("Work Hard")
# Out:
# Enter your number:  8
# Good

# %%
a=int(input("Enter 1st number: "))
b=int(input("Enter 2nd number: "))
c=int(input("Enter 3rd number: "))
if a<b and c<b:
    print(f"{b} is the greatest among all three")
elif a>b and a>c:
    print(f"{a} is the greatest among all three")
else:
    print(f"{c} is the greatest among all three")
# Out:
# Enter 1st number:  25
# Enter 2nd number:  45
# Enter 3rd number:  36
# 45 is the greatest among all three
