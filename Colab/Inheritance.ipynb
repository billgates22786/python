# %%
class Suresh:
  pen="Parker"
class Kartikay:
  pencil="Natraj"
  def use(self):
    s=Suresh()
    print(s.pen)
    print(self.pencil)
K=Kartikay()
K.use()
# Out:
# Parker
# Natraj

# %%
class AgeTooSmallError(Exception):
    def __init__(self, message="Age is too small to vote"):
        self.message = message
        super().__init__(self.message)

age = int(input("Enter your age: "))
try:
    if age < 18:
        raise AgeTooSmallError
    else:
        print("You are eligible to vote.")
except AgeTooSmallError as e:
    print("Error:", e)
# Out:
# Enter your age: 15
# Error: Age is too small to vote

# %%
class Suresh:
  pen="Parker"
class Kartikay(Suresh):
  pencil="Natraj"
  def use(self):

    print(self.pen)
    print(self.pencil)
K=Kartikay()
K.use()
# Out:
# Parker
# Natraj

# %%
class Suresh:
  pen="Parker"
class Kartikay(Suresh):
  pencil="Natraj"
class Manit(Kartikay):
  eraser="Sensil"
  def use(self):

    print(self.pen)
    print(self.pencil)
    print(self.eraser)

M=Manit()
M.use()
# Out:
# Parker
# Natraj
# Sensil

# %%
class Suresh:
  pen="Parker"
class Kartikay:
  pencil="Natraj"
class Manit(Suresh,Kartikay):
  eraser="Sensil"
  def use(self):

    print(self.pen)
    print(self.pencil)
    print(self.eraser)

M=Manit()
M.use()
# Out:
# Parker
# Natraj
# Sensil

# %%
a=10
b="pop"
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-2523249646> in <cell line: 0>()
#       1 a=10
#       2 b="pop"
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
  n1=int(input("Enter first number = "))
  n2=int(input("Enter second number = "))
except:
  print("Dont Divide a value by zero")
finally:
  print("End of the program")
# Out:
# Enter first number = 0
# Enter second number = 0
# End of the program

# %%
try:
  n1=int(input("Enter first number = "))
  n2=int(input("Enter second number = "))
except ZeroDivisionError as Z:
  print(Z)
finally:
  print("End of the program")
# Out:
# Enter first number = 0
# Enter second number = 0
# End of the program

# %%
try:
  n1=int(input("Enter first number = "))
  n2=int(input("Enter second number = "))
  result=n1/n2
except ZeroDivisionError as Z:
  print(Z)
else:
  print(result)
finally:
  print("End of the program")
# Out:
# Enter first number = 10
# Enter second number = 0
# division by zero
# End of the program

# %%
try:
  n1=int(input("Enter first number = "))
  n2=int(input("Enter second number = "))
  result=n1/n2
except ZeroDivisionError as Z:41
  print(Z)
except ValueError as V:
  print(V)
except KeyboardInterrupt as K:
  print(K)
else:
  print(result)
finally:
  print("End of the program")
# Out:
# Enter first number = jk
# invalid literal for int() with base 10: 'jk'
# End of the program

# %%
class Somerror(Exception):
 def __init__(self,message="Sum is greater than 10"):
    self.message=message
    super().__init__(message)
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
total=a+b
try:
  if total>10:
    raise Somerror
  else:
    print("Great no error!!")
except Somerror as e:
    print("Error: ",e)
# Out:
# Enter first number: 25
# Enter second number: 5
# Error:  Sum is greater than 10
