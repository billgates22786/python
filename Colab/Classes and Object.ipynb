# %%
import sys
class Student:
  pass
obj=Student
print(obj)
print(type(obj))
print(sys.getsizeof(obj))
objj=Student()
print(objj)
print(type(objj))
print(sys.getsizeof(obj))
# Out:
# <class '__main__.Student'>
# <class 'type'>
# 1688
# ...
# <class '__main__.Student'>
# 1688

# %%
class Student:
  name="kiran"
  rollno=1
print("Student Name=",Student.name)
print("Student Roll No=",Student.rollno)
# Out:
# Student Name= kiran
# Student Roll No= 1

# %%
class Student:
  name="kiran"
  rollno=1

obj=Student
print("Student Name=",obj.name)
print("Student Roll No=",obj.rollno)
# Out:
# Student Name= kiran
# Student Roll No= 1

# %%
class Student:
  def input():
    Student.name="Kiran"
    Student.rollno=1
  def output():
    print("Student Name=",Student.name)
    print("Student Rollno=",Student.rollno)

# %%
Student.input()
Student.output()
# Out:
# Student Name= Kiran
# Student Rollno= 1

# %%
class cl:
  def input():
    cl.one=int(input("Enter one number:"))
    cl.two=int(input("Enter second number:"))
    cl.add=cl.one+cl.two
  def output():
    print("Sum of two numbers=",cl.add)

# %%
cl.input()
cl.output()
# Out:
# Enter one number:234
# Enter second number:23
# Sum of two numbers= 257

# %%
class Animals:
  def_init_(self):
    print("Constructor")
