# %%
name=input("Enter your name= ")
rollNo=input("Enter your roll Number= ")
fee=input("Enter your fee= ")
gender=input("Enter your gender= ")
print(name)
print(rollNo)
print(fee)
print(gender)
print(type(name))
print(type(rollNo))
print(type(fee))
print(type(gender))
# Out:
# Enter your name=  Kartikay Jain
# Enter your roll Number=  21
# Enter your fee=  1805.52
# Enter your gender=  Male
# Kartikay Jain
# 21
# 1805.52
# Male
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
name=input("Enter your name= ")
rollNo=int(input("Enter your roll Number= "))
fee=float(input("Enter your fee= "))
gender=input("Enter your gender= ")
print(name)
print(rollNo)
print(fee)
print(gender)
print(type(name))
print(type(rollNo))
print(type(fee))
print(type(gender))
# Out:
# Enter your name=  manoj
# Enter your roll Number=  1
# Enter your fee=  12.12
# Enter your gender=  M
# manoj
# 1
# 12.12
# M
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
print(type({}))
print(type([]))
print(type(()))
# Out:
# <class 'dict'>
# <class 'list'>
# <class 'tuple'>

# %%
p=65
print(p)
print(chr(p))
# Out:
# 65
# A

# %%
p='A'
print(p)
print(ord(p))
# Out:
# A
# 65

# %%
marks=int(input("Enter marks: "))
# Out:
# Enter marks:  25

# %%
p=55
print(chr(p))
# Out:
# 7

# %%
name="Kartikay Jain"
age= 19
string="My name is {} and I am {} years old.".format(name,age)
print(string)
string=f"My name is {name} and I am {age} years old."
print(string)
# Out:
# My name is Kartikay Jain and I am 19 years old.
# My name is Kartikay Jain and I am 19 years old.
