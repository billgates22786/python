# %%
class student:
  pass
obj=student
print(obj)
print(type(obj))
print(id(obj))
print(id(student))

objj=student()
print(objj)
print(type(objj))
print(id(objj))
print(id(student))
# Out:
# <class '__main__.student'>
# <class 'type'>
# 165612896
# 165612896
# ...
# <class '__main__.student'>
# 134429600254608
# 165612896

# %%
class student:
  name="Hari"
  rollno=1

print("Student name = ",student.name)
print("Student roll no = ",student.rollno)
# Out:
# Student name =  Hari
# Student roll no =  1

# %%
class student:
  def input():
    student.name="Hari"
    student.rollno=1
  def output():
    print("Student name = ",student.name)
    print("Student roll no = ",student.rollno)

# %%
student.input()
student.output()
# Out:
# Student name =  Hari
# Student roll no =  1

# %%
class student:
  def stuinput(name,rollno):
    student.name=name
    student.rollno=rollno
  def stuoutput():
    print("Student name = ",student.name)
    print("Student roll no = ",student.rollno)
# Out:
# Destructor calling
# Destructor calling

# %%
student.stuinput("Kiran",1)
student.stuoutput()
# Out:
# Student name =  Kiran
# Student roll no =  1

# %%
student.stuinput(input("Enter your name="),int(input("Enter your rollno=")))
student.stuoutput()
# Out:
# Enter your name=kartikay
# Enter your rollno=1
# Student name =  kartikay
# Student roll no =  1

# %%
class student:
  def stuinput(name,rollno):
    student.name=name
    student.rollno=rollno
  def stuoutput():
    print("Student name = ",student.name)
    print("Student roll no = ",student.rollno)

# %%
s=student()
s.stuinput(input("Enter your name="),int(input("Enter your rollno=")))
s.stuoutput()
# Out:
# Enter your name=kartikay
# Enter your rollno=1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-178632915> in <cell line: 0>()
#       1 s=student()
# ----> 2 s.stuinput(input("Enter your name="),int(input("Enter your rollno=")))
#       3 s.stuoutput()
#
# TypeError: student.stuinput() takes 2 positional arguments but 3 were given

# %%
class student:
  def stuinput(self,name,rollno):
    student.name=name
    student.rollno=rollno
  def stuoutput(self):
    print("Student name = ",student.name)
    print("Student roll no = ",student.rollno)

# %%
s=student()
s.stuinput(input("Enter your name="),int(input("Enter your rollno=")))
s.stuoutput()

# %%
class Student:
  __Name=None
  __Rollno=None
  __Age=None
  #Setters
  def setName(self,Name):
    self.__Name=Name
  def setRollno(self,Rollno):
    self.__Rollno=Rollno
  def setAge(self,Age):
    self.__Age=Age
  #Getters

  def getName(self):
    return self.__Name
  def getRollno(self):
    return self.__Rollno
  def getAge(self):
    return self.__Age

  StuName=property(getName,setName)
  StuRollno=property(getRollno,setRollno)
  StuAge=property(getAge,setAge)

# %%
S=Student()
S.StuName="Harry"
S.StuRollno=1
S.StuAge=21
print("Stuedent Name=",S.StuName)
print("Stuedent Rollno=",S.StuRollno)
print("Stuedent Age=",S.StuAge)

# %%
class Hello:
  def __init__(self):
    print("Constructor calling automatically")

  def normalmethod(self):
    print("Normal method calling...")

  def __del__(self):
    print("Destructor calling")

obj=Hello()
obj.normalmethod()

objj=Hello()
objj.normalmethod()
# Out:
# Constructor calling automatically
# Normal method calling...
# Constructor calling automatically
# Normal method calling...
