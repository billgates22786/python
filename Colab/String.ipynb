# %%
# Access character of a string
x="Hi my name is Kartikay Jain"
print(x[-4])
print(x[0])
# Out:
# J
# H

# %%
# Acessing a chunk of letters/characters from a string
x=" hello and welcome to the apoco n11 of the space marshalls"
print(x[0:5])
# Out:
#  hell

# %%
# Updating a portion of a string
x="Hello"
y=x[:4]+'boy'
print(y)
# Out:
# Hellboy

# %%
# Concatenation/join of strings
x="GOD"
y="EVIL"
z=x+y
print(z)
# Out:
# GODEVIL

# %%
# Repition of a string
x="Hell"*3
print(x)
# Out:
# HellHellHell

# %%
# Iterate throught a string
x="godevil"
for i in x:
  print(i)
# Out:
# g
# o
# d
# e
# v
# i
# l

# %%
# Checking if a substring is present in a String or not
x="Hellboy"
if "Hell" in x:
  print("yes")
else:
  print("no")
# Out:
# yes

# %%
# String formatting using 'format( )' method
x=3
y=4
z=x+y
result="The added value of {} and {} is {}"
print(result.format(x,y,z))
results="The added value of {1} and {0} is {2}"
print(results.format(x,y,z))
Results="The added value of {p} and {q} is {r}"
print(Results.format(p=x,q=y,r=z))
# Out:
# The added value of 3 and 4 is 7
# The added value of 4 and 3 is 7
# The added value of 3 and 4 is 7

# %%
# String formatting operator %
x=3
y=4
z=x+y
print("The added value of %d and %d is %d"%(x,y,z))
# Out:
# The added value of 3 and 4 is 7

# %%
# Methods to handle strings
x="Godevil"
print("The length of the string is",len(x))
# Out:
# The length of the string is 7

# %%
# 1. Let the variable word be "Computers". Print the:
# ● First character
# ● Last character
# ● Middle four characters
# ● Last five characters
# ● First three characters
x="Computers"
print(f"First character: {x[0]}")
print(f"Last character: {x[-1]}")
print(f"Middle four character: {x[2:6]}")
print(f"Last five character: {x[-5:]}")
print(f"First three character: {x[:3]}")
# Out:
# First character: C
# Last character: s
# Middle four character: mput
# Last five character: uters
# First three character: Com

# %%
# Prompt the user for eight words. Return the average length of the words entered Prompt the user for eight words. Return the average length of the words entered by the user.
n=input("Enter eight words: ")
if len(n)!=8:
  print("Invalid input!")
else:
  Total=len(n)/8
  print(f"Average word length: {Total/len(n)}")
# Out:
# Enter eight words: qwerrqwe
# Average word length: 1.0

# %%
# Repeat the same program, but do not specify ahead of time how many words the user will enter. Have them enter words until they input the word "STOP". Then, display the average length of the words entered by the user.
total=0
while len(n):
  n=input("Enter a word (STOP to finish): ")
  if n=="STOP":
    break
  total+=len(n)

print(f"Average word: {total/len(n)}")
# Out:
# Enter a word (STOP to finish): qwfjfuerjjgio
# Enter a word (STOP to finish): stop
# Enter a word (STOP to finish): STOP
# Average word: 4.25

# %%
# 4. Gather a word from the user and display:
# ● Its letters one per line.
# ● Its letters in reverse order, one per line.

# ● It with every letter 'e' removed.
x=input("Enter your word: ")
print("Displaying letter one per line")
for i in x:
  print(i)
print("Displaying letters in reverse order, one per line ")
for i in x[::-1]:
  print(i)

print("Displaying letter to remove e")
s=x.replace('e','')
print(f"Without letter 'e': {s}")
# Out:
# Enter your word: seen
# Displaying letter one per line
# s
# e
# e
# n
# Displaying letters in reverse order, one per line
# n
# e
# e
# s
# Without letter 'e': sn

# %%
# ● It with its second and second-to-last letters exchanged. (e.g., "banana" →" bnnaaa")
n=input("Enter your word: ")
for i in n:
  if n[-2]:
# Out:
# Enter your word: kartikay
# k
# k
# k
# k
# k
# k
# k
# k
# k

# %%
# Capitalize String
string= "solo leveling last ep was Ms"
cap_string= string.capitalize()
print("Old string",string)
print("Capitalized string",cap_string)
# Out:
# Old string solo leveling last ep was Ms
# Capitalized string Solo leveling last ep was ms

# %%
# Python string center
string="Python is awesome"
new_string=string.center(50)
print("Centered string: ",new_string)
# Out:
# Centered string:                  Python is awesome

# %%
# Python string casefold
string="PYTHON IS AWESOME"
# print lowercase string
print("Lowercase string: ",string.casefold())
# Out:
# Lowercase string:  python is awesome

# %%
# PYTHON STRING COUNT
string="Pytho is awesome, isn't it isotope?"
substring="is"
count=string.count(substring)
print("The count is: ",count)
# Out:
# The count is:  3

# %%
# PYTHON STRING ENDSWITH()
text= "Python is easy to learn."
result=text.endswith("to learn")
print(result)
result=text.endswith("to learn.")
print(result)
result=text.endswith("Python is easy to learn.")
print(result)
# Out:
# False
# True
# True

# %%
# PYHTON STRING ENXPANDTABS()
str="xyz\t12345\tabc"
stra="my\n12345\nabc"
result=str.expandtabs()
r=stra.expandtabs()
print(result)
print(r)
# Out:
# xyz     12345   abc
# my
# 12345
# abc

# %%
# Python string find() method
quote="Let it be, let it be, let it be"
result=quote.find('let it')
print("Substring 'let it':",result)
result=quote.find('small')
print("Substring 'small':",result)
if (quote.find('be,') != -1):
  print("Contains substring 'be,'")
else:
  print("Doesn't contain substring")
# Out:
# Substring 'let it': 11
# Substring 'small': -1
# Contains substring 'be,'

# %%
# default arguments
print("Hello {}, your balance is {}.".format("Adam", 230.2346))
# positional arguments
print("Hello {0}, your balance is {1}.".format("Adam", 230.2346))
# keyword arguments
print("Hello {name}, your balance is {blc}.".format(name="Adam", blc=230.2346))
# mixed arguments
print("Hello {0}, your balance is {blc}.".format("Adam", blc=230.2346))
# Out:
# Hello Adam, your balance is 230.2346.
# Hello Adam, your balance is 230.2346.
# Hello Adam, your balance is 230.2346.
# Hello Adam, your balance is 230.2346.

# %%
# PYTHON STRING INDEX
sentence="Python progamming is fun."
result=sentence.index("is fun")
print("Substring is fun:",result)
result=sentence.index("JAva")
print(result)
# the main difference between find() and index() is that in index it shows error if substring is not found but in the case of find() it shows -1 if the string is not found
# Out:
# Substring is fun: 18
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ddb4d04b5c6c> in <cell line: 0>()
#       3 result=sentence.index("is fun")
#       4 print("Substring is fun:",result)
# ----> 5 result=sentence.index("JAva")
#       6 print(result)
#
# ValueError: substring not found

# %%
# title()
k=input("Enter a sentence: ")
k.title()
# Out:
# Enter a sentence: the harmonius fight between godevil and son jinwoo break into a apocalyptic inter galatic situation which caused chaos every where and in result it all goes south
# 'The Harmonius Fight Between Godevil And Son Jinwoo Break Into A Apocalyptic Inter Galatic Situation Which Caused Chaos Every Where And In Result It All Goes South '

# %%
# islowe()
stro="the spd rangers was one of the best shows among all the other pr shows of all time "
stro.islower()
lop="DOP KOP"
lop.lower()
# Out:
# 'dop kop'

# %%
# isupper()
sr="python developer"
sr.isupper()
sro="PYTHON"
sro.isupper()
# Out:
# True

# %%
# lower() and upper()
sa="Python"
ka=sa.lower()
print(ka)
print(ka.upper())
# Out:
# python
# PYTHON

# %%
# len()
sr="Attack on titan and solo leveling"
fr=""" himintopu
jiijjpjj"""
print("Length of multi line string",len(fr))
print("Length of the string:",len(sr))
# Out:
# Length of multi line string 21
# Length of the string: 33
