# %%
import pandas as pd
df=pd.read_csv('PCOMPANY.csv')
print("Our DataFrame:-\n",df)
# Out:
# Our DataFrame:-
#       Pid      Pname  Pcompany  PatyStock  Sales
# 0   1001        Lux       H&l        225     50
# 1   1002        Rim       H&l        350     60
# 2   1003  Pepsodent   Colgate        560     71
# 3   1004      Pepsi  CocaCola       1200     21
# 4   1005   CocaCola  CocaCola       1200     26
# 5   1006      Liril       ABC        750     29
# 6   1007     Camera     Canon         55     30
# 7   1008  Projector    Parker         56     37
# 8   1009        Pen    Parker       1100     25
# 9   1010     Marker    Parker       1200     26
# 10  1011   Register       DOM       1500     15
# 11  1012    Shampoo    Loreal       1250     19
# 12  1013     Mobile     Apple        760     21
# 13  1014     Remote        Lg        250     22
# 14  1015      Shirt     Zudio        960     10

# %%
print(df.columns)
# Out:
# Index(['Pid', 'Pname', 'Pcompany', 'PatyStock', 'Sales'], dtype='object')

# %%
df.shape
# Out:
# (15, 5)

# %%
df.insert(loc=5, column="Prate", value=(50,60,70,80,90,100,110,120,140,150,200,580,620,410,450))
df
# Out:
#      Pid      Pname  Pcompany  PatyStock  Sales  Prate
# 0   1001        Lux       H&l        225     50     50
# 1   1002        Rim       H&l        350     60     60
# 2   1003  Pepsodent   Colgate        560     71     70
# 3   1004      Pepsi  CocaCola       1200     21     80
# 4   1005   CocaCola  CocaCola       1200     26     90
# 5   1006      Liril       ABC        750     29    100
# 6   1007     Camera     Canon         55     30    110
# 7   1008  Projector    Parker         56     37    120
# 8   1009        Pen    Parker       1100     25    140
# 9   1010     Marker    Parker       1200     26    150
# 10  1011   Register       DOM       1500     15    200
# 11  1012    Shampoo    Loreal       1250     19    580
# 12  1013     Mobile     Apple        760     21    620
# 13  1014     Remote        Lg        250     22    410
# 14  1015      Shirt     Zudio        960     10    450

# %%
df.insert(loc=6,column="AmountPayable",value=(df.eval('Sales*Prate')))
df
# Out:
#      Pid      Pname  Pcompany  PatyStock  Sales  Prate  AmountPayable
# 0   1001        Lux       H&l        225     50     50           2500
# 1   1002        Rim       H&l        350     60     60           3600
# 2   1003  Pepsodent   Colgate        560     71     70           4970
# 3   1004      Pepsi  CocaCola       1200     21     80           1680
# 4   1005   CocaCola  CocaCola       1200     26     90           2340
# 5   1006      Liril       ABC        750     29    100           2900
# 6   1007     Camera     Canon         55     30    110           3300
# 7   1008  Projector    Parker         56     37    120           4440
# 8   1009        Pen    Parker       1100     25    140           3500
# 9   1010     Marker    Parker       1200     26    150           3900
# 10  1011   Register       DOM       1500     15    200           3000
# 11  1012    Shampoo    Loreal       1250     19    580          11020
# ...

# %%
df.loc[0, 'Prate']=48
df.loc[0,'AmountPayable']=2400
df
# Out:
#      Pid      Pname  Pcompany  PatyStock  Sales  Prate  AmountPayable
# 0   1001        Lux       H&l        225     50     48           2400
# 1   1002        Rim       H&l        350     60     60           3600
# 2   1003  Pepsodent   Colgate        560     71     70           4970
# 3   1004      Pepsi  CocaCola       1200     21     80           1680
# 4   1005   CocaCola  CocaCola       1200     26     90           2340
# 5   1006      Liril       ABC        750     29    100           2900
# 6   1007     Camera     Canon         55     30    110           3300
# 7   1008  Projector    Parker         56     37    120           4440
# 8   1009        Pen    Parker       1100     25    140           3500
# 9   1010     Marker    Parker       1200     26    150           3900
# 10  1011   Register       DOM       1500     15    200           3000
# 11  1012    Shampoo    Loreal       1250     19    580          11020
# ...

# %%
df[df["Pname"].str.startswith("P")]
# Out:
#     Pid      Pname  Pcompany  PatyStock  Sales  Prate  AmountPayable
# 2  1003  Pepsodent   Colgate        560     71     70           4970
# 3  1004      Pepsi  CocaCola       1200     21     80           1680
# 7  1008  Projector    Parker         56     37    120           4440
# 8  1009        Pen    Parker       1100     25    140           3500

# %%
df1=df.rename(columns={'Pid': 'PRODUCT_ID', 'Pname': 'PRODUCT_NAME','Prate':'PRODUCT_RATE'})
df1
# Out:
#     PRODUCT_ID PRODUCT_NAME  Pcompany  PatyStock  Sales  PRODUCT_RATE  \
# 0         1001          Lux       H&l        225     50            48
# 1         1002          Rim       H&l        350     60            60
# 2         1003    Pepsodent   Colgate        560     71            70
# 3         1004        Pepsi  CocaCola       1200     21            80
# 4         1005     CocaCola  CocaCola       1200     26            90
# 5         1006        Liril       ABC        750     29           100
# 6         1007       Camera     Canon         55     30           110
# 7         1008    Projector    Parker         56     37           120
# 8         1009          Pen    Parker       1100     25           140
# 9         1010       Marker    Parker       1200     26           150
# 10        1011     Register       DOM       1500     15           200
# 11        1012      Shampoo    Loreal       1250     19           580
# ...

# %%
df[df['Pname'].str.len()==3]
# Out:
#     Pid Pname Pcompany  PatyStock  Sales  Prate  AmountPayable
# 0  1001   Lux      H&l        225     50     48           2400
# 1  1002   Rim      H&l        350     60     60           3600
# 8  1009   Pen   Parker       1100     25    140           3500

# %%
df['Pname'] = df['Pname'].str.upper()
df['Pcompany']=df['Pcompany'].str.upper()
df
# Out:
#      Pid      Pname  Pcompany  PatyStock  Sales  Prate  AmountPayable
# 0   1001        LUX       H&L        225     50     48           2400
# 1   1002        RIM       H&L        350     60     60           3600
# 2   1003  PEPSODENT   COLGATE        560     71     70           4970
# 3   1004      PEPSI  COCACOLA       1200     21     80           1680
# 4   1005   COCACOLA  COCACOLA       1200     26     90           2340
# 5   1006      LIRIL       ABC        750     29    100           2900
# 6   1007     CAMERA     CANON         55     30    110           3300
# 7   1008  PROJECTOR    PARKER         56     37    120           4440
# 8   1009        PEN    PARKER       1100     25    140           3500
# 9   1010     MARKER    PARKER       1200     26    150           3900
# 10  1011   REGISTER       DOM       1500     15    200           3000
# 11  1012    SHAMPOO    LOREAL       1250     19    580          11020
# ...

# %%
df.insert(loc=7,column="Category",value=("Soap","Soap","Toothpaste","Softdrink","Softdrink","Unknown","Electronics","Electronics","Stationary","Stationary","Stationary","HairProducts","Electronics","Electronics","Clothes"))
df
# Out:
#      Pid      Pname  Pcompany  PatyStock  Sales  Prate  AmountPayable  \
# 0   1001        LUX       H&L        225     50     48           2400
# 1   1002        RIM       H&L        350     60     60           3600
# 2   1003  PEPSODENT   COLGATE        560     71     70           4970
# 3   1004      PEPSI  COCACOLA       1200     21     80           1680
# 4   1005   COCACOLA  COCACOLA       1200     26     90           2340
# 5   1006      LIRIL       ABC        750     29    100           2900
# 6   1007     CAMERA     CANON         55     30    110           3300
# 7   1008  PROJECTOR    PARKER         56     37    120           4440
# 8   1009        PEN    PARKER       1100     25    140           3500
# 9   1010     MARKER    PARKER       1200     26    150           3900
# 10  1011   REGISTER       DOM       1500     15    200           3000
# 11  1012    SHAMPOO    LOREAL       1250     19    580          11020
# ...

# %%
df.loc[5, 'Category']= 'Soap'
df
# Out:
#      Pid      Pname  Pcompany  PatyStock  Sales  Prate  AmountPayable  \
# 0   1001        LUX       H&L        225     50     48           2400
# 1   1002        RIM       H&L        350     60     60           3600
# 2   1003  PEPSODENT   COLGATE        560     71     70           4970
# 3   1004      PEPSI  COCACOLA       1200     21     80           1680
# 4   1005   COCACOLA  COCACOLA       1200     26     90           2340
# 5   1006      LIRIL       ABC        750     29    100           2900
# 6   1007     CAMERA     CANON         55     30    110           3300
# 7   1008  PROJECTOR    PARKER         56     37    120           4440
# 8   1009        PEN    PARKER       1100     25    140           3500
# 9   1010     MARKER    PARKER       1200     26    150           3900
# 10  1011   REGISTER       DOM       1500     15    200           3000
# 11  1012    SHAMPOO    LOREAL       1250     19    580          11020
# ...

# %%
categoryCounts=df.groupby('Category').size()
categoryCounts
# Out:
# Category
# Clothes         1
# Electronics     4
# HairProducts    1
# Soap            3
# Softdrink       2
# Stationary      3
# Toothpaste      1
# dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['Soap', 'Toothpaste', 'Softdrink', 'Electronics', 'Stationary',
#        'HairProducts', 'Clothes'], dtype=object)

# %%
df.to_html("Pcompany.html")

# %%
df.to_json("Pcompany1.json")

# %%
df
# Out:
#      Pid      Pname  Pcompany  PatyStock  Sales  Prate  AmountPayable  \
# 0   1001        LUX       H&L        225     50     48           2400
# 1   1002        RIM       H&L        350     60     60           3600
# 2   1003  PEPSODENT   COLGATE        560     71     70           4970
# 3   1004      PEPSI  COCACOLA       1200     21     80           1680
# 4   1005   COCACOLA  COCACOLA       1200     26     90           2340
# 5   1006      LIRIL       ABC        750     29    100           2900
# 6   1007     CAMERA     CANON         55     30    110           3300
# 7   1008  PROJECTOR    PARKER         56     37    120           4440
# 8   1009        PEN    PARKER       1100     25    140           3500
# 9   1010     MARKER    PARKER       1200     26    150           3900
# 10  1011   REGISTER       DOM       1500     15    200           3000
# 11  1012    SHAMPOO    LOREAL       1250     19    580          11020
# ...

# %%
df=df.sort_values(by='Pname')
df
# Out:
#      Pid      Pname  Pcompany  PatyStock  Sales  Prate  AmountPayable  \
# 6   1007     CAMERA     CANON         55     30    110           3300
# 4   1005   COCACOLA  COCACOLA       1200     26     90           2340
# 5   1006      LIRIL       ABC        750     29    100           2900
# 0   1001        LUX       H&L        225     50     48           2400
# 9   1010     MARKER    PARKER       1200     26    150           3900
# 12  1013     MOBILE     APPLE        760     21    620          13020
# 8   1009        PEN    PARKER       1100     25    140           3500
# 3   1004      PEPSI  COCACOLA       1200     21     80           1680
# 2   1003  PEPSODENT   COLGATE        560     71     70           4970
# 7   1008  PROJECTOR    PARKER         56     37    120           4440
# 10  1011   REGISTER       DOM       1500     15    200           3000
# 13  1014     REMOTE        LG        250     22    410           9020
# ...

# %%
df.groupby("Category").sum([df["AmountPayable"]])
# Out:
#                Pid  PatyStock  Sales  Prate  AmountPayable
# Category
# Clothes       1015        960     10    450           4500
# Electronics   4042       1121    110   1260          29780
# HairProducts  1012       1250     19    580          11020
# Soap          3009       1325    139    208           8900
# Softdrink     2009       2400     47    170           4020
# Stationary    3030       3800     66    490          10400
# Toothpaste    1003        560     71     70           4970

# %%
df.to_csv("Pcompany_csv.csv")

# %%
df
# Out:
#      Pid      Pname  Pcompany  PatyStock  Sales  Prate  AmountPayable  \
# 6   1007     CAMERA     CANON         55     30    110           3300
# 4   1005   COCACOLA  COCACOLA       1200     26     90           2340
# 5   1006      LIRIL       ABC        750     29    100           2900
# 0   1001        LUX       H&L        225     50     48           2400
# 9   1010     MARKER    PARKER       1200     26    150           3900
# 12  1013     MOBILE     APPLE        760     21    620          13020
# 8   1009        PEN    PARKER       1100     25    140           3500
# 3   1004      PEPSI  COCACOLA       1200     21     80           1680
# 2   1003  PEPSODENT   COLGATE        560     71     70           4970
# 7   1008  PROJECTOR    PARKER         56     37    120           4440
# 10  1011   REGISTER       DOM       1500     15    200           3000
# 13  1014     REMOTE        LG        250     22    410           9020
# ...

# %%
import matplotlib.pyplot as p
import matplotlib.image as img
x=df["Pname"]
y=df["Sales"]
# p.bar(df["Pname"],df["Sales"])
p.bar(x,y,width=0.5)
p.xlabel("Products")
p.ylabel("Sales")
size="xx-small"
p.xticks(rotation=90)
for i, v in enumerate(y):
    p.text(i, v + 3, str(v), ha='center', va='bottom', fontsize="xx-small")
p.show()
