# %%
# %timeit range(10)
# Out:
# 104 ns ± 7.76 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
pip install snakeviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %timeit range(20)
# Out:
# 103 ns ± 4.62 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%timeit
for i
